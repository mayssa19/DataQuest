# %% [markdown]
# [Data description](https://github.com/mayssa19/data/tree/master/college-majors)

# %% [markdown]
# ## Importing libraries and reading the data

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
% matplotlib inline
recent_grads = pd.read_csv("recent-grads.csv")

#return the first row of the data
print(recent_grads.iloc[0])
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
#return the first row of the data
print(recent_grads.iloc[0])
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
#display the first rows of the data
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
# display the last rows of the data
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
recent_grads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 21 columns):
# Rank                    173 non-null int64
# Major_code              173 non-null int64
# Major                   173 non-null object
# Total                   172 non-null float64
# Men                     172 non-null float64
# Women                   172 non-null float64
# Major_category          173 non-null object
# ShareWomen              172 non-null float64
# Sample_size             173 non-null int64
# Employed                173 non-null int64
# Full_time               173 non-null int64
# Part_time               173 non-null int64
# Full_time_year_round    173 non-null int64
# Unemployed              173 non-null int64
# Unemployment_rate       173 non-null float64
# Median                  173 non-null int64
# P25th                   173 non-null int64
# P75th                   173 non-null int64
# College_jobs            173 non-null int64
# ...

# %%
ax = recent_grads.plot(x='Full_time', y='Sample_size', kind='scatter')

# %%
ax = recent_grads.plot(x='Total', y='Sample_size', kind='scatter')

# %% [markdown]
# ## Statistical description of the data

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %% [markdown]
# ## Drop rows with missing values

# %%
raw_data_count = recent_grads.shape[0]
raw_data_count
# Out:
# 173

# %%
recent_grads = recent_grads.dropna()

# %%
cleaned_data_count = recent_grads.shape[0]
cleaned_data_count
# Out:
# 172

# %% [markdown]
# ## Scatter plots

# %%
ax = recent_grads.plot(x='Sample_size', y='Median', kind='scatter')
ax.set_title('Median vs. Sample_size')
# Out:
# Text(0.5,1,'Median vs. Sample_size')

# %%
ax = recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')
ax.set_title('Unemployment_rate vs. Sample_size')
# Out:
# Text(0.5,1,'Unemployment_rate vs. Sample_size')

# %%
ax = recent_grads.plot(x='Full_time', y='Median', kind='scatter')
ax.set_title('Median vs. Full_time')
# Out:
# Text(0.5,1,'Median vs. Full_time')

# %% [markdown]
# * The scatter plot of "Median vs. Full_time" does not show a strong relation between the two variables. Hence, we can not conclude that the median salary increases with the number of full-time employees.

# %%
ax = recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter')
ax.set_title('ShareWomen vs.Unemployment_rate')
# Out:
# Text(0.5,1,'ShareWomen vs.Unemployment_rate')

# %% [markdown]
# * There is no correlation between the ShareWomen and the unemployment_rate.

# %%
ax = recent_grads.plot(x='Men', y='Median', kind='scatter')
ax.set_title('Median vs. Men')
# Out:
# Text(0.5,1,'Median vs. Men')

# %%
recent_grads.plot(x='Women', y='Median', kind='scatter')

# %%
recent_grads.plot(x='Sample_size', y='Full_time_year_round', kind='scatter')

# %%
g = sns.swarmplot(x="Major_category", y="Median", data=recent_grads);
_, labels = plt.xticks()
g.set_xticklabels(labels, rotation=90)
# Out:
# [Text(0,0,'Engineering'),
#  Text(0,0,'Business'),
#  Text(0,0,'Physical Sciences'),
#  Text(0,0,'Law & Public Policy'),
#  Text(0,0,'Computers & Mathematics'),
#  Text(0,0,'Industrial Arts & Consumer Services'),
#  Text(0,0,'Arts'),
#  Text(0,0,'Health'),
#  Text(0,0,'Social Science'),
#  Text(0,0,'Biology & Life Science'),
#  Text(0,0,'Education'),
#  Text(0,0,'Agriculture & Natural Resources'),
#  Text(0,0,'Humanities & Liberal Arts'),
#  Text(0,0,'Psychology & Social Work'),
#  Text(0,0,'Communications & Journalism'),
#  Text(0,0,'Interdisciplinary')]

# %%
recent_grads[["Major_category", "Total"]].groupby(['Major_category'],as_index=False).sum().sort_values\
(by='Total', ascending=False)
# Out:
#                          Major_category      Total
# 3                              Business  1302376.0
# 9             Humanities & Liberal Arts   713468.0
# 6                             Education   559129.0
# 7                           Engineering   537583.0
# 15                       Social Science   529966.0
# 14             Psychology & Social Work   481007.0
# 8                                Health   463230.0
# 2                Biology & Life Science   453862.0
# 4           Communications & Journalism   392601.0
# 1                                  Arts   357130.0
# 5               Computers & Mathematics   299008.0
# 10  Industrial Arts & Consumer Services   229792.0
# 13                    Physical Sciences   185479.0
# 12                  Law & Public Policy   179107.0
# 0       Agriculture & Natural Resources    75620.0
# 11                    Interdisciplinary    12296.0

# %% [markdown]
# * The most popular major is business, however, in the above swarmplot, students in the engineering field make the more money. Hence, students in more popular majors does not necessarly earn more money.

# %% [markdown]
# ## Earnings based on gender

# %%
Major_gender = recent_grads[["Major_category", "Men","Women","Median"]].groupby(['Major_category'], as_index=False).sum()
Major_men = Major_gender[['Major_category',"Median"]][Major_gender['Men'] > Major_gender['Women']]

# %%
Major_women = Major_gender[['Major_category',"Median"]][Major_gender['Men'] < Major_gender['Women']]

# %%
g = sns.swarmplot(x="Major_category", y="Median", data=Major_men);
_, labels = plt.xticks()
g.set_xticklabels(labels, rotation=90)
g.set_title("earnings of Major_men")
# Out:
# Text(0.5,1,'earnings of Major_men')

# %%
g = sns.swarmplot(x="Major_category", y="Median", data=Major_women);
_, labels = plt.xticks()
g.set_xticklabels(labels, rotation=90)
g.set_title("earnings of Major_women")
# Out:
# Text(0.5,1,'earnings of Major_women')

# %% [markdown]
#  * The second plot in this section describes the earnings in majors where the majority are females, however, they don't make more money compared to the plot showing the earnings in majors where the majority are men.

# %% [markdown]
# ## Histograms

# %%
recent_grads['Sample_size'].plot(kind='hist')

# %%
recent_grads['Median'].plot(kind='hist')

# %% [markdown]
# * The distribution of the median salary is skewed right and the most common range is between 30000 and 40000.

# %%
recent_grads['Employed'].plot(kind='hist')

# %%
recent_grads['Full_time'].plot(kind='hist')

# %%
recent_grads['ShareWomen'].plot(kind='hist')

# %% [markdown]
# * The disribution of ShareWomen is almost skewed left where almost 70 % of majors are predominantly female and the rest (30%) are predominantly male.

# %%
recent_grads['Unemployment_rate'].plot(kind='hist')

# %% [markdown]
# * The unemployment rate follows a normal distribution and the most common range among majors falls into [0.06, 0.07]

# %%
recent_grads['Men'].plot(kind='hist')

# %%
recent_grads['Women'].plot(kind='hist')

# %% [markdown]
# Use the plots to explore the following questions:
# What percent of majors are predominantly male? Predominantly female?
# What's the most common median salary range?
# * The histograms show that

# %% [markdown]
# ## Scatter matrices

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(6,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a17bfb438>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median','Unemployment_rate']],figsize=(6,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a17fd9cf8>,
# ...
#       dtype=object)

# %% [markdown]
# ## Bar plots

# %% [markdown]
# #### Comparing the percentages of women

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen',legend = False)
recent_grads[163:].plot.bar(x='Major', y='ShareWomen',legend = False)

# %% [markdown]
# * The bar plots show that the percentages of women increased in terms of earnings in the last 10 rows comapred with the first 10 rows.

# %% [markdown]
# #### Comparing the unemployment rate

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate',legend = False)
recent_grads[162:].plot.bar(x='Major', y='Unemployment_rate',legend = False)

# %% [markdown]
# * The percentages of unemployment rates are less in the last ten rows compared with the 10 first rows.
